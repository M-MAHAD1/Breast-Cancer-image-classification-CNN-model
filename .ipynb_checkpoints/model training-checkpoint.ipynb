# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
train_val_path = r"C:\Users\MAHAD\Desktop\Breast Cancer Project\Dataset\breast"        # original dataset (train + val)
test_path = r"C:\Users\MAHAD\Desktop\Breast Cancer Project\Dataset\breast_test"        # test dataset

# %%
img_size = (224, 224)
batch_size = 16

# %%
# Train + Validation Generator
datagen = ImageDataGenerator(
    rescale=1./255,          # Normalize
    validation_split=0.2     # 20% validation
)

train_data = datagen.flow_from_directory(
    train_val_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

val_data = datagen.flow_from_directory(
    train_val_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 6328 images belonging to 2 classes.
# Found 1581 images belonging to 2 classes.

# %%
# Test Generator
test_datagen = ImageDataGenerator(rescale=1./255)
test_data = test_datagen.flow_from_directory(
    test_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 800 images belonging to 2 classes.

# %%
# STEP 3: Model Architecture
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),
    
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')   # Binary output
])
# Out:
# C:\Users\MAHAD\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ...

# %%
# STEP 4: Model Training
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 265s 663ms/step - accuracy: 0.7664 - loss: 0.5457 - val_accuracy: 0.8058 - val_loss: 0.4302
# Epoch 2/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 197s 497ms/step - accuracy: 0.8161 - loss: 0.4684 - val_accuracy: 0.8444 - val_loss: 0.4244
# Epoch 3/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 194s 491ms/step - accuracy: 0.8173 - loss: 0.4580 - val_accuracy: 0.7919 - val_loss: 0.4418
# Epoch 4/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 196s 494ms/step - accuracy: 0.8029 - loss: 0.4813 - val_accuracy: 0.8330 - val_loss: 0.5083
# Epoch 5/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 198s 501ms/step - accuracy: 0.8236 - loss: 0.4563 - val_accuracy: 0.7065 - val_loss: 0.5224
# Epoch 6/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 198s 498ms/step - accuracy: 0.8295 - loss: 0.4412 - val_accuracy: 0.8634 - val_loss: 0.3402
# Epoch 7/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 197s 497ms/step - accuracy: 0.8284 - loss: 0.4398 - val_accuracy: 0.8457 - val_loss: 0.3702
# Epoch 8/10
# ...

# %%
# STEP 5: Model Evaluation
loss, acc = model.evaluate(test_data)
print("Test Accuracy:", acc)
print("Test Loss:", loss)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 358ms/step - accuracy: 0.8475 - loss: 0.4018
# Test Accuracy: 0.8475000262260437
# Test Loss: 0.40182173252105713

# %%
# STEP 6: Simple Hyperparameter Tuning
model_tuned = Sequential([
    Conv2D(64, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),
    
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    
    Conv2D(256, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(1, activation='sigmoid')
])

# %%
model_tuned.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

history_tuned = model_tuned.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 678s 2s/step - accuracy: 0.8088 - loss: 0.4745 - val_accuracy: 0.8444 - val_loss: 0.3839
# Epoch 2/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 690s 2s/step - accuracy: 0.8336 - loss: 0.4122 - val_accuracy: 0.8482 - val_loss: 0.3592
# Epoch 3/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 783s 2s/step - accuracy: 0.8429 - loss: 0.3834 - val_accuracy: 0.8121 - val_loss: 0.5161
# Epoch 4/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 781s 2s/step - accuracy: 0.8534 - loss: 0.3554 - val_accuracy: 0.7312 - val_loss: 0.6133
# Epoch 5/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 785s 2s/step - accuracy: 0.8549 - loss: 0.3390 - val_accuracy: 0.8495 - val_loss: 0.3840
# Epoch 6/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 787s 2s/step - accuracy: 0.8677 - loss: 0.3188 - val_accuracy: 0.8748 - val_loss: 0.3235
# Epoch 7/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 818s 2s/step - accuracy: 0.8712 - loss: 0.2937 - val_accuracy: 0.7881 - val_loss: 0.5213
# Epoch 8/10
# ...

# %%
# Evaluate tuned model on test data
loss_tuned, acc_tuned = model_tuned.evaluate(test_data)

print("Tuned Model Test Accuracy:", acc_tuned)
print("Tuned Model Test Loss:", loss_tuned)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 312ms/step - accuracy: 0.8587 - loss: 0.3091
# Tuned Model Test Accuracy: 0.8587499856948853
# Tuned Model Test Loss: 0.3091491162776947

# %%
import matplotlib.pyplot as plt

# %%
# Untuned model metrics
acc_base = history.history['accuracy']
val_acc_base = history.history['val_accuracy']
loss_base = history.history['loss']
val_loss_base = history.history['val_loss']

# %%
# Tuned model metrics
acc_tuned = history_tuned.history['accuracy']
val_acc_tuned = history_tuned.history['val_accuracy']
loss_tuned = history_tuned.history['loss']
val_loss_tuned = history_tuned.history['val_loss']

epochs = range(1, len(acc_base) + 1)

# %%
# ---- ACCURACY GRAPH ----
plt.figure(figsize=(10,5))
plt.plot(epochs, acc_base, label='Untuned Train Acc')
plt.plot(epochs, val_acc_base, label='Untuned Val Acc')
plt.plot(epochs, acc_tuned, label='Tuned Train Acc')
plt.plot(epochs, val_acc_tuned, label='Tuned Val Acc')
plt.title('Training & Validation Accuracy Comparison')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.savefig('Acc_comparison.png')
plt.show()

# %%
# ---- LOSS GRAPH ----
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_base, label='Untuned Train Loss')
plt.plot(epochs, val_loss_base, label='Untuned Val Loss')
plt.plot(epochs, loss_tuned, label='Tuned Train Loss')
plt.plot(epochs, val_loss_tuned, label='Tuned Val Loss')
plt.title('Training & Validation Loss Comparison')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('loss_comparison.png')
plt.show()

# %%
model_tuned.save("breast_cancer_model_tuned.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
